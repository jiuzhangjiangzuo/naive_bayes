# %% [markdown]
# # 垃圾邮件分类
#
# https://www.kaggle.com/uciml/sms-spam-collection-dataset

# %% [markdown]
# 读取数据

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt # 画图常用库

data_dir = "../input/"

df = pd.read_csv(data_dir + '/spam.csv', encoding='latin-1')  
# 编码相关阅读http://blog.csdn.net/robertcpp/article/details/7837712 

# 查看数据
df.head()
df.v1.head()
# Out:
# 0     ham
# 1     ham
# 2    spam
# 3     ham
# 4     ham
# Name: v1, dtype: object

# %% [markdown]
# 把数据拆分为train 和 test

# %%
from sklearn.model_selection import train_test_split

# split data into training set and testing set
data_train, data_test, labels_train, labels_test = train_test_split(df.v2, df.v1, test_size=0.2, random_state=0)
# Out:
# 1114    ham
# 3589    ham
# 3095    ham
# 1012    ham
# 3320    ham
# Name: v1, dtype: object

# %% [markdown]
# 统计训练集里面单词个数

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
# 只用训练集的单词来建立词库，
data_train_count = vectorizer.fit_transform(data_train)
data_test_count  = vectorizer.transform(data_test)
print(data_train_count.shape)
print(data_test_count.shape)
print (vectorizer.vocabulary_)
# Out:
# (4457, 7612)
# (1115, 3690)
# {'could': 902, 'tomo': 3292, 'tim': 3262, 'students': 3079, 'granite': 1473, 'standard': 3033, 'power': 2513, 'northampton': 2271, 'request': 2697, 'via': 3438, 'tyler': 3358, 'weeks': 3521, 'pod': 2480, 'mid': 2091, 'lect': 1882, 'easy': 1122, 'flat': 1318, 'hour': 1611, 'costå': 900, 'soon': 2981, 'nok': 2262, 'shuhui': 2888, 'decimal': 981, 'pizza': 2452, 'bathe': 558, 'blimey': 617, 'aå': 529, 'subscription': 3093, 'costa': 898, 'spend': 3005, 'abi': 326, 'tm': 3275, 'bx420': 703, 'cuz': 947, '08452810073': 29, 'conditions': 869, 'ps': 2575, 'real': 2636, 'moment': 2145, '09066380611': 92, 'goodnite': 1456, 'quick': 2599, 'mag': 2005, 'staff': 3029, 'compare': 859, 'mins': 2105, 'uh': 3362, 'idu': 1656, 'alrite': 412, 'source': 2992, 'gal': 1396, 'puttin': 2590, 'officer': 2311, 'slice': 2930, 'paperwork': 2385, 'scotland': 2797, 'math': 2043, 'dan': 954, 'our': 2362, 'heater': 1550, 'against': 379, 'stuff': 3083, 'scraped': 2798, 'tot': 3308, 'their': 3219, '83383': 291, 'others': 2357, 'means': 2062, 'yrs': 3667, 'row': 2747, 'sport': 3021, '2nhite': 171, 'anything': 451, 'both': 648, 'velachery': 3430, 'appt': 468, 'pa': 2371, 'want': 3485, 'computer': 866, 'suganya': 3103, 'usps': 3415, 'nag': 2206, 'gay': 1410, 'ey': 1243, 'forth': 1347, 'suite342': 3106, 'aiyah': 396, 'payments': 2408, 'ages': 382, 'sec': 2806, 'random': 2616, 'er': 1181, 'partner': 2392, '7th': 275, 'software': 2958, 'law': 1867, 'its': 1737, 'hoo': 1594, 'ec2a': 1126, '5000': 240, 'fights': 1286, 'wotu': 3608, 'thenampet': 3223, 'surrender': 3127, 'ebay': 1125, 'babes': 534, 'frnds': 1374, 'representative': 2696, 'early': 1117, 'hustle': 1642, '1131': 109, 'wat': 3496, 'scrumptious': 2801, 'personal': 2423, 'chapter': 770, 'ramaduth': 2614, 'imf': 1669, 'spoilt': 3016, 'isnåõt': 1731, 'o2fwd': 2299, 'lover': 1975, 'asus': 502, 'dudes': 1106, 'elvis': 1146, '35p': 193, 'shitin': 2869, 'across': 347, 'com': 847, 'we': 3503, '12hrs': 117, 'drink': 1088, 'stealing': 3050, 'trip': 3327, 'erotic': 1185, 'thats': 3213, 'chart': 776, 'badly': 538, '08715203685': 52, 'ese': 1187, 'married': 2033, 'call': 709, '3230': 187, 'river': 2729, 'kalisidare': 1794, 'askd': 492, 'reminding': 2680, 'dirty': 1038, 'poortiyagi': 2493, 'lousy': 1969, '14tcr': 122, 'explosive': 1237, 'cancel': 729, 'muz': 2199, 'remains': 2675, 'pound': 2509, 'giv': 1435, 'bath': 557, 'wrnog': 3617, 'carlin': 742, 'adp': 362, 'draws': 1083, 'hello': 1554, 'shrek': 2887, 'humans': 1633, 'sleeping': 2924, 'pobox114': 2475, 'natural': 2220, '7cfca1a': 272, 'dialogue': 1017, 'wtc': 3621, 'posible': 2497, 'pleassssssseeeeee': 2463, 'till': 3261, 'dog': 1060, 'spoiled': 3015, 'pretend': 2544, 'close': 826, 'wkg': 3580, 'invited': 1718, 'harry': 1531, 'charged': 773, 'evaporated': 1196, 'aha': 386, 'knackered': 1828, 'urgent': 3401, 'almost': 407, 'thew': 3229, 'schools': 2794, 'annoying': 439, 'yoga': 3658, 'ha': 1503, '6230': 257, 'tgxxrz': 3203, 'bluff': 628, 'inconvenient': 1682, '2yrs': 179, 'cheaper': 781, 'review': 2711, '09065171142': 86, 'drunk': 1099, 'sporadically': 3020, 'wet': 3532, 'yesterday': 3650, 'thru': 3251, 'details': 1009, 'gauge': 1407, '3030': 183, 'finance': 1298, 'fancies': 1255, 'month': 2153, '1im': 139, 'largest': 1857, 'issues': 1733, 'toclaim': 3281, 'rain': 2610, 'apology': 460, 'experiencehttp': 1233, 'studyn': 3082, 'clock': 824, 'link': 1920, 'polys': 2489, 'nalla': 2208, 'every': 1202, 'mistakes': 2117, 'maga': 2006, 'skillgame': 2918, 'bsn': 680, 'deposited': 1001, 'project': 2567, 'touch': 3311, '6times': 266, 'hopeu': 1600, 'prompts': 2571, 'hurting': 1639, 'bin': 602, 'not': 2273, 'halloween': 1513, 'entitled': 1178, 'cedar': 757, 'sue': 3100, '47': 218, 'hospital': 1604, 'car': 735, 'recently': 2648, 'wkend': 3578, 'cn': 835, 'plans': 2456, 'child': 791, 'speeding': 3003, 'final': 1296, 'hurry': 1637, 'london': 1947, 'jaz': 1761, 'weakness': 3505, 'wall': 3477, 'karo': 1796, 'lady': 1848, 'sooooo': 2984, 'describe': 1005, 'bout': 652, 'commercial': 855, ' ...

# %% [markdown]
# 演示CountVectorizer用法

# %%
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt # 画图常用库
vect = CountVectorizer()
example = ['Banana, Carry', 'Fuck Dan']

#fit: 统计单词成表，并且每个单词给一个id

#transform: 统计term-document matrix
result = vect.fit_transform(example)
print(result)
print (vect.stop_words_)
print (vect.vocabulary_)
# Out:
#   (0, 1)	1
#   (0, 0)	1
#   (1, 2)	1
#   (1, 3)	1
# set()
# {'carry': 1, 'dan': 2, 'banana': 0, 'fuck': 3}

# %% [markdown]
# 选择比较重要的feature

# %% [markdown]
# 训练模型

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

clf = MultinomialNB()
clf.fit(data_train_count, labels_train)
predictions = clf.predict(data_test_count)
print(predictions)
# Out:
# ['ham' 'ham' 'ham' ..., 'ham' 'ham' 'ham']

# %%
print(accuracy_score(labels_test, predictions))
# Out:
# 0.987443946188
